# %% [markdown]
# <a href="https://colab.research.google.com/github/AoifMurphy/PythonProjectExercises/blob/master/Covid_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
global_data = pd.read_csv(r'https://covid19.who.int/WHO-COVID-19-global-data.csv')
global_data.head()
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-03           AF  Afghanistan       EMRO          0
# 1    2020-01-04           AF  Afghanistan       EMRO          0
# 2    2020-01-05           AF  Afghanistan       EMRO          0
# 3    2020-01-06           AF  Afghanistan       EMRO          0
# 4    2020-01-07           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0           0                  0
# 1                 0           0                  0
# 2                 0           0                  0
# 3                 0           0                  0
# 4                 0           0                  0

# %%
global_data.describe()
# Out:
#           New_cases  Cumulative_cases     New_deaths  Cumulative_deaths
# count  2.867700e+05      2.867700e+05  286770.000000       2.867700e+05
# mean   2.665810e+03      1.250508e+06      24.114398       1.663237e+04
# std    3.905500e+04      5.859306e+06     144.649623       7.126501e+04
# min   -8.261000e+03      0.000000e+00   -3520.000000       0.000000e+00
# 25%    0.000000e+00      1.499000e+03       0.000000       1.300000e+01
# 50%    1.100000e+01      2.939400e+04       0.000000       3.220000e+02
# 75%    3.520000e+02      3.413030e+05       4.000000       4.997000e+03
# max    6.966046e+06      1.030815e+08   11447.000000       1.121819e+06

# %%
vaccination_data = pd.read_csv(r'https://covid19.who.int/who-data/vaccination-data.csv')
vaccination_data.info
# Out:
# <bound method DataFrame.info of                COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0          Afghanistan  AFG       EMRO   REPORTING   2023-04-25
# 1              Albania  ALB       EURO   REPORTING   2023-03-19
# 2              Algeria  DZA       AFRO   REPORTING   2022-09-04
# 3       American Samoa  ASM       WPRO   REPORTING   2023-03-29
# 4              Andorra  AND       EURO   REPORTING   2023-02-26
# ..                 ...  ...        ...         ...          ...
# 224           Viet Nam  VNM       WPRO   REPORTING   2023-04-20
# 225  Wallis and Futuna  WLF       WPRO   REPORTING   2023-01-23
# 226              Yemen  YEM       EMRO   REPORTING   2023-04-18
# 227             Zambia  ZMB       AFRO   REPORTING   2023-04-09
# 228           Zimbabwe  ZWE       AFRO   REPORTING   2023-04-23
#
#      TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 0            16847327.0                       14735342
# ...

# %%
vaccination_data.describe()
# Out:
#        TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# count        2.280000e+02                   2.290000e+02
# mean         5.852351e+07                   2.422316e+07
# std          2.836544e+08                   1.138253e+08
# min          1.380000e+02                   0.000000e+00
# 25%          4.672435e+05                   1.914030e+05
# 50%          4.665630e+06                   2.740227e+06
# 75%          2.275058e+07                   1.073245e+07
# max          3.515873e+09                   1.317995e+09
#
#        TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# count                 227.000000                            229.000000
# mean                  154.108956                             63.527537
# std                    84.208722                             25.634507
# min                     0.312000                              0.000000
# 25%                    83.350000                             45.187000
# ...

# %%
vaccination_data.columns
# Out:
# Index(['COUNTRY', 'ISO3', 'WHO_REGION', 'DATA_SOURCE', 'DATE_UPDATED',
#        'TOTAL_VACCINATIONS', 'PERSONS_VACCINATED_1PLUS_DOSE',
#        'TOTAL_VACCINATIONS_PER100', 'PERSONS_VACCINATED_1PLUS_DOSE_PER100',
#        'PERSONS_FULLY_VACCINATED', 'PERSONS_FULLY_VACCINATED_PER100',
#        'VACCINES_USED', 'FIRST_VACCINE_DATE', 'NUMBER_VACCINES_TYPES_USED',
#        'PERSONS_BOOSTER_ADD_DOSE', 'PERSONS_BOOSTER_ADD_DOSE_PER100'],
#       dtype='object')

# %%
vaccines = pd.read_csv(r'https://covid19.who.int/who-data/vaccination-metadata.csv')
vaccines.head()
# Out:
#   ISO3                 VACCINE_NAME PRODUCT_NAME     COMPANY_NAME  \
# 0  GRL          Moderna - mRNA-1273    mRNA-1273          Moderna
# 1  SHN        AstraZeneca - AZD1222      AZD1222      AstraZeneca
# 2  FRO          Moderna - mRNA-1273    mRNA-1273          Moderna
# 3  FRO  Pfizer BioNTech - Comirnaty    Comirnaty  Pfizer BioNTech
# 4  BIH        AstraZeneca - AZD1222      AZD1222      AstraZeneca
#
#   AUTHORIZATION_DATE START_DATE  END_DATE  COMMENT DATA_SOURCE
# 0                NaN        NaN       NaN      NaN        OWID
# 1                NaN        NaN       NaN      NaN        OWID
# 2                NaN        NaN       NaN      NaN        OWID
# 3                NaN        NaN       NaN      NaN        OWID
# 4                NaN        NaN       NaN      NaN        OWID

# %%
vaccines.tail()
# Out:
#      ISO3                                       VACCINE_NAME  \
# 1090  FRA  Pfizer BioNTech - Comirnaty Bivalent Original/...
# 1091  LVA  Pfizer BioNTech - Comirnaty Bivalent Original/...
# 1092  DEU  Moderna – Spikevax Bivalent Original/Omicron  ...
# 1093  DEU  Pfizer BioNTech - Comirnaty Bivalent Original/...
# 1094  SVN  Pfizer BioNTech - Comirnaty Bivalent Original/...
#
#                                            PRODUCT_NAME COMPANY_NAME  \
# 1090      Comirnaty Bivalent Original/Omicron BA.4/BA.5          NaN
# 1091      Comirnaty Bivalent Original/Omicron BA.4/BA.5          NaN
# 1092  Moderna – Spikevax Bivalent Original/Omicron  ...          NaN
# 1093  Pfizer BioNTech - Comirnaty Bivalent Original/...          NaN
# 1094  Pfizer BioNTech - Comirnaty Bivalent Original/...          NaN
#
#      AUTHORIZATION_DATE  START_DATE  END_DATE  COMMENT DATA_SOURCE
# 1090                NaN  2022-10-05       NaN      NaN   REPORTING
# ...

# %%
vaccines.describe()
# Out:
#        END_DATE  COMMENT
# count       0.0      0.0
# mean        NaN      NaN
# std         NaN      NaN
# min         NaN      NaN
# 25%         NaN      NaN
# 50%         NaN      NaN
# 75%         NaN      NaN
# max         NaN      NaN

# %%
vaccines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ISO3                1095 non-null   object
#  1   VACCINE_NAME        1095 non-null   object
#  2   PRODUCT_NAME        1094 non-null   object
#  3   COMPANY_NAME        1051 non-null   object
#  4   AUTHORIZATION_DATE  490 non-null    object
#  5   START_DATE          808 non-null    object
#  6   END_DATE            0 non-null      float64
#  7   COMMENT             0 non-null      float64
#  8   DATA_SOURCE         1095 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 77.1+ KB
